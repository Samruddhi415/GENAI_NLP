# %%
import nltk
nltk.download("all")

# %%
from nltk.tokenize import sent_tokenize, word_tokenize

# %%
text = "Delhi CM Rekha Gupta Oath Taking Ceremony Live Updates: Delhi’s chief minister-designate Rekha Gupta will be taking oath as the head of the state at the Ramlila Maidan today at around noon, with senior BJP leaders, including Prime Minister Narendra Modi, Union Home Minister Amit Shah and others in attendance. Earlier in the morning, it was made official that MLAs Parvesh Verma and Kapil Mishra would be part of the Delhi Cabinet. Rekha Gupta is the only female BJP leader currently elevated to the office of chief minister."

# %%
print(word_tokenize(text))

# %%
print(sent_tokenize(text))

# %%
from nltk.stem import SnowballStemmer
snowball = SnowballStemmer(language='english')
words = ["running", "runner", "runs", "swimming", "swimmer", "swims"]
stemmed_words = [snowball.stem(word) for word in words]

print("Snowball Stemmer Output:")
for original, stemmed in zip(words, stemmed_words):
    print(f"{original} -> {stemmed}")

# %%
# import these modules
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()

print("rocks :", lemmatizer.lemmatize("rocks"))
print("corpora :", lemmatizer.lemmatize("corpora"))

# a denotes adjective in "pos"
print("better :", lemmatizer.lemmatize("better", pos="a"))
